# %% [markdown]
# <a href="https://colab.research.google.com/github/saecula/notebooks/blob/main/Udacity_1_The_Data_Science_Process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/drive/Othercomputers/My MacBook Pro/synced/Udacity/survey-results-public.csv')
schema = pd.read_csv('/content/drive/Othercomputers/My MacBook Pro/synced/Udacity/survey-results-schema.csv')

# %%
# entry = schema[schema.Column == 'CompanyType']
# otherthing = schema.loc[schema['Column'] == 'aaa']
# print(entry.Question.values[0])
# print(otherthing.Question.values[0])


def get_description(column_name, schema=schema):
    '''
    INPUT - schema - pandas dataframe with the schema of the developers survey
            column_name - string - the name of the column you would like to know about
    OUTPUT -
            desc - string - the description of the column
    '''
    desc = schema.loc[schema.Column == column_name].Question.values[0]
    return desc

#test your code
#Check your function against solution - you shouldn't need to change any of the below code
get_description(df.columns[0]) # This should return a string of the first column description

# return 1 if ed_value in ("Bachelors", "Masters")
def is_higher_ed(ed_value):
    higher_ed = ["Master's degree", "Professional degree"]
    if ed_value in higher_ed:
        return 1
    else:
        return 0

df['HigherEd'] = df.FormalEducation.apply(is_higher_ed)

# %%
ed_1 = df[df['HigherEd'] == 1].reset_index()

print(ed_1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11856 entries, 0 to 11855
# Columns: 156 entries, index to HigherEd
# dtypes: float64(6), int64(3), object(147)
# memory usage: 14.1+ MB
# None

# %%
ndf = df.select_dtypes(include='number')
print(ndf.corr())
# Out:
#                            Respondent  CareerSatisfaction  JobSatisfaction  \
# Respondent                   1.000000           -0.015348        -0.016278
# CareerSatisfaction          -0.015348            1.000000         0.645803
# JobSatisfaction             -0.016278            0.645803         1.000000
# HoursPerWeek                 0.023430           -0.067544        -0.081532
# StackOverflowSatisfaction    0.037309            0.155679         0.087871
# Salary                      -0.026780            0.158223         0.120765
# ExpectedSalary              -0.009201            0.003346              NaN
# HigherEd                    -0.011336           -0.008974         0.001005
#
#                            HoursPerWeek  StackOverflowSatisfaction    Salary  \
# Respondent                     0.023430                   0.037309 -0.026780
# CareerSatisfaction            -0.067544                   0.155679  0.158223
# ...

# %%
import numpy as np


def histogram_intersection(a, b):
     v = np.minimum(a, b).sum().round(decimals=1)
     return v

cddf = pd.DataFrame([(.2, .3), (.0, .6), (.6, .0), (.2, .1)],
                   columns=['dogs', 'cats'])
cddf.corr(method=histogram_intersection)
# Out:
#       dogs  cats
# dogs   1.0   0.3
# cats   0.3   1.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['dogs'].plot(kind='hist', bins=20, title='dogs')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['cats'].plot(kind='hist', bins=20, title='cats')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='dogs', y='cats', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...
